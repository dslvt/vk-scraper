# %%
import pickle

# %%
posts = pickle.load(open("posts.pkl", "rb"))

# %%
len(posts)
# Out:
# 430

# %%
posts[420]
# Out:
# {'response': {'count': 43782,
#   'items': [{'id': 7027,
#     'from_id': -92876084,
#     'owner_id': -92876084,
#     'date': 1461717604,
#     'marked_as_ads': 0,
#     'donut': {'is_donut': False},
#     'comments': {'can_post': 0,
#      'count': 0,
#      'donut': {'placeholder': {'text': 'Чтобы видеть больше комментариев и\xa0оставлять свои, поддержите сообщество.'}}},
#     'short_text_rate': 0.8,
#     'attachments': [],
#     'is_favorite': False,
#     'likes': {'can_like': 1, 'count': 324, 'user_likes': 0, 'can_publish': 1},
#     'post_source': {'type': 'api'},
#     'post_type': 'post',
#     'reposts': {'count': 5, 'user_reposted': 0},
#     'signer_id': 24467766,
# ...
